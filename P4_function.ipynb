# %% [markdown]
# http://gis.stackexchange.com/questions/163785/using-python-to-compute-the-distance-between-coordinates-lat-long-using-havers

# %%
import math
def distance_on_unit_sphere(lat1, long1, lat2, long2):
    # Convert latitude and longitude to 
    # spherical coordinates in radians.
    degrees_to_radians = math.pi/180.0
         
    # phi = 90 - latitude
    phi1 = (90.0 - lat1)*degrees_to_radians
    phi2 = (90.0 - lat2)*degrees_to_radians
         
    # theta = longitude
    theta1 = long1*degrees_to_radians
    theta2 = long2*degrees_to_radians
         
    # Compute spherical distance from spherical coordinates.
         
    # For two locations in spherical coordinates 
    # (1, theta, phi) and (1, theta, phi)
    # cosine( arc length ) = 
    #    sin phi sin phi' cos(theta-theta') + cos phi cos phi'
    # distance = rho * arc length
     
    cos = (math.sin(phi1)*math.sin(phi2)*math.cos(theta1 - theta2) + 
           math.cos(phi1)*math.cos(phi2))
    arc = math.acos( cos )
    # Remember to multiply arc by the radius of the earth 
    # in your favorite set of units to get length.
    return arc*6373
print distance_on_unit_sphere(22.9979057, 120.22208048, 22.99774354, 120.22210156)
# Out:
# 0.0181656595435

# %%
import urllib2
import json

# Automatically geolocate the connecting IP
f = urllib2.urlopen('http://freegeoip.net/json/')
json_string = f.read()
f.close()
location = json.loads(json_string)
print(location)
location_city = location['city']
location_state = location['region_name']
location_country = location['country_name']
location_zip = location['zipcode']
# Out:
# {u'city': u'', u'region_code': u'', u'region_name': u'', u'ip': u'140.122.53.22', u'time_zone': u'Asia/Taipei', u'longitude': 121, u'metro_code': 0, u'latitude': 23.5, u'country_code': u'TW', u'country_name': u'Taiwan', u'zip_code': u''}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-f6a318d32bdb> in <module>()
#      11 location_state = location['region_name']
#      12 location_country = location['country_name']
# ---> 13 location_zip = location['zipcode']
#
# KeyError: 'zipcode'

# %%
import json
import urllib2

def location_lookup():
  try:
    return json.load(urllib2.urlopen('http://ipinfo.io/json'))
  except urllib2.HTTPError:
    return False

location = location_lookup()

# print city and latitude/longitude
print location['city'] + ' (' + location['loc'] + ')'
# Out:
#  (23.5000,121.0000)

# %%
import urllib
import json
import gzip
url = 'http://data.taipei/youbike'
urllib.urlretrieve(url, "data.gz")
data_str = gzip.open('data.gz', 'r').read()
data = json.loads(data_str)

# %% [markdown]
# # hahaha
# * 123412314
# * http://www.yahoo.com.tw

# %%
print a
# Out:
# here

# %%
def afunction(a, b, c):
    return c, b, a
d, e, f = afunction(1, 3, [1, 3, 2])

astring = 'here is a string'
a, b =  astring.split()[:2]
a, b, c = c, b, a
print a
# Out:
# here

# %%
print a
# Out:
# here

# %%
for site1 in data['retVal'].values():
    for site2 in data['retVal'].values():
# Out:
# 25.10336 121.522629 捷運芝山站(2號出口)
# 25.114513 121.515677 捷運石牌站(2號出口)
# 25.118049 121.517512 國立臺北護理健康大學
# 25.137976 121.493066 國防大學
# 25.058 121.61422 南港世貿公園
# 25.02665 121.52889 臺灣師範大學(圖書館)
# 25.01603085 121.5331757 羅斯福新生南路口
# 25.111839 121.525888 蘭興公園
# 25.059978 121.533302 捷運行天宮站(3號出口)
# 25.058369 121.532934 捷運行天宮站(1號出口)
# 25.0337 121.528988 捷運東門站(4號出口)
# 25.02101 121.54153 臺大資訊大樓
# 25.022413 121.53456 辛亥新生路口
# 25.017054 121.544352 基隆長興路口
# 25.04878 121.56087 中崙高中
