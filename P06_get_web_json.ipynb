# %% [markdown]
# # Let's review the ubike scraping code

# %%
import requests
import json
url  = 'http://data.taipei/youbike'
response = requests.get(url)
data = json.loads(response.text)
print("response code:", response.status_code)
# Out:
# response code: 200

# %% [markdown]
# # Prac: Use above code to get back the following data

# %%
url_AQX = "https://taqm.epa.gov.tw/taqm/aqs.ashx?lang=tw&act=aqi-epa&ts=1538961147679"
url_dcard = "https://www.dcard.tw/_api/forums/girl/posts?popular=true"
url_pchome = "http://ecshweb.pchome.com.tw/search/v3.3/all/results?q=X100F&page=1&sort=rnk/dc"
url_104 = "https://www.104.com.tw/jobs/search/list?ro=0&keyword=%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90&area=6001001000&order=1&asc=0&kwop=7&page=2&mode=s&jobsource=n104bank1"

# %% [markdown]
# # Write a function to load json data

# %%
def get_web_json(url):
    response = requests.get(url)
    print("response code:", response.status_code)
    if not response.ok:
        return None
    data = json.loads(response.text)
    return data

# %%
data = get_web_json(url_591)
print(data)
# Out:
# response code: 404
# None

# %%
response = requests.get(url_591)

# %%
response.ok
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-1a4aab9917d1> in <module>()
# ----> 1 response.ok
#
# AttributeError: 'dict' object has no attribute 'ok'

# %% [markdown]
# ## Use requests.json()

# %%
data = requests.get(url_dcard).json()
type(data)
# Out:
# list

# %%
data[0]
# Out:
# {'id': 229814982,
#  'title': '跟20年的長髮掰掰👋',
#  'excerpt': '小女 子 我從小時候有記憶以來就都是長頭髮，最短大概也是肩下5公分左右的中長髮吧🤔，每次看到身邊的人剪我都很想剪，但又很害怕自己剪起來很醜，加上母親又是長髮控，每次都說我短髮一定很醜，（哪有人這樣說自己女兒的？？？）',
#  'anonymousSchool': True,
#  'anonymousDepartment': True,
#  'pinned': False,
#  'forumId': 'f72e3b1d-3c9a-4fec-8a61-41c76cc317af',
#  'replyId': None,
#  'createdAt': '2018-10-09T03:45:46.180Z',
#  'updatedAt': '2018-10-10T07:39:55.335Z',
#  'commentCount': 69,
#  'likeCount': 2060,
#  'withNickname': False,
#  'tags': [],
#  'topics': ['髮型', '短髮'],
#  'forumName': '女孩',
#  'forumAlias': 'girl',
#  'gender': 'F',
#  'replyTitle': None,
#  'supportedReactions': [],
#  'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 2060}],
#  'hidden': False,
#  'customStyle': None,
#  'withImages': True,
#  'withVideos': False,
#  'media': [{'url': 'https://i.imgur.com/GtftTj1.jpg'},
#   {'url': 'https://i.imgur.com/2Gypxwm.jpg'},
#   {'url': 'https://i.imgur.com/CMlAhNf.jpg'},
#   {'url': 'https://i.imgur.com/egqVQJN.jpg'},
#   {'url': 'https://i.imgur.com/4z8d3tf.jpg'},
#   {'url': 'https://i.imgur.com/L99Ozxw.jpg'},
#   {'url': 'https://i.imgur.com/q45L34D.jpg'},
#   {'url': 'https://i.imgur.com/fc1mPSj.jpg'},
#   {'url': 'https://i.imgur.com/7xPqeGZ.jpg'},
#   {'url': 'https://i.imgur.com/o1e6EnB.jpg'},
#   {'url': 'https://i.imgur.com/mShfD11.jpg'},
#   {'url': 'https://i.imgur.com/MeWc8kN.jpg'}]}

# %% [markdown]
# # Prac: Problmatic url? See requests doc
# * Try to get back the url https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind=2&searchtype=1&region=1
# * You will get an 404 status_code
# * Solution: https://stackoverflow.com/questions/10606133/sending-user-agent-using-requests-library-in-python
#
# ## Parameters of a request
# * Quick start of requests library http://docs.python-requests.org/en/master/user/quickstart/
# ```
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
# Accept-Encoding: gzip, deflate, br
# Accept-Language: en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7,zh-CN;q=0.6
# Cache-Control: max-age=0
# Connection: keep-alive
# Cookie: webp=1; PHPSESSID=74131f35fb441ebacf685a6552f2629b; T591_TOKEN=74131f35fb441ebacf685a6552f2629b; urlJumpIp=1; urlJumpIpByTxt=%E5%8F%B0%E5%8C%97%E5%B8%82; 591_new_session=%3D
# Host: rent.591.com.tw
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36
# ```

# %%
url_591 = "https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind=2&searchtype=1&region=1"
response = requests.get(url_591)
response.ok
# Out:
# False

# %%
headers = {
    'User-Agent': 'Chrome/69.0.3497.100'
} # headers are sent by dict form
response = requests.get(url_591, headers=headers).json()
# response.ok

# %%
type(response)
response.keys()
response["data"]["data"]
# Out:
# [{'id': 6784977,
#   'user_id': 2169784,
#   'address': '南海路2巷捷運站旁..',
#   'type': '1',
#   'post_id': 6784977,
#   'regionid': 1,
#   'sectionid': 1,
#   'streetid': 25811,
#   'room': 0,
#   'area': 14,
#   'price': '17,000',
#   'storeprice': 0,
#   'comment_total': 4,
#   'comment_unread': 4,
#   'comment_ltime': 1538901440,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 3,
#   'houseage': 0,
#   'posttime': '3分鐘內',
#   'updatetime': 1536627603,
#   'refreshtime': 1539176402,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,landpost,trabus,balcony_1,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2018/09/11/153662657174722804_210x158.crop.jpg',
#   'browsenum': 115,
#   'browsenum_all': 4247,
#   'floor2': 0,
#   'floor': 3,
#   'ltime': '2018-10-10 21:00:21',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '涂先生',
#   'housetype': 1,
#   'street_name': '南海路',
#   'alley_name': '2巷',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '捷運站旁~全新裝潢+第一手入住',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 4,
#   'floorInfo': '樓層：3/4',
#   'house_img': '119114676,119114677,119114678,119114679,119114680,119114681,119114682,119114683,119114699,119114700,119114701,119114703,119114706,119114709,119114711,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,中正租屋,獨立套房出租,捷運站旁~全新裝潢+第一手入住',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 4,
#   'comment_class': '',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '15',
#   'filename': 'https://hp1.591.com.tw/house/active/2018/09/11/153662657174722804_210x158.crop.jpg',
#   'nick_name': '屋主 涂先生',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '中正區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '南海路2巷捷運站旁~全新裝潢+第一手入住',
#   'address_img_title': '捷運站旁~全新裝潢+第一手入住',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6784977,
#   'region_name': '台北市',
#   'section_name': '中正區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6825745,
#   'user_id': 167309,
#   'address': '林森北路✔電梯✔磁..',
#   'type': '1',
#   'post_id': 6825745,
#   'regionid': 1,
#   'sectionid': 3,
#   'streetid': 25716,
#   'room': 0,
#   'area': 11,
#   'price': '18,000',
#   'storeprice': 0,
#   'comment_total': 2,
#   'comment_unread': 2,
#   'comment_ltime': 1537880275,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '3分鐘內',
#   'updatetime': 1538727637,
#   'refreshtime': 1539176402,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,lift,pet,cook,balcony_0,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2018/10/05/153872761325638209_210x158.crop.jpg',
#   'browsenum': 204,
#   'browsenum_all': 3844,
#   'floor2': 0,
#   'floor': 3,
#   'ltime': '2018-10-10 21:00:23',
#   'cases_id': '',
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '林先生',
#   'housetype': 3,
#   'street_name': '林森北路',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '✔電梯✔磁卡進出✔代收垃圾✔裝潢新✔秒殺',
#   'cases_name': '以現場為主',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 3,
#   'floorInfo': '樓層：3/3',
#   'house_img': '120919955,120919958,120919959,120919961,119979501,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,中山租屋,獨立套房出租,✔電梯✔磁卡進出✔代收垃圾✔裝潢新✔秒殺',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 2,
#   'comment_class': '',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '5',
#   'filename': 'https://hp1.591.com.tw/house/active/2018/10/05/153872761325638209_210x158.crop.jpg',
#   'nick_name': '仲介 林先生',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '中山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '林森北路✔電梯✔磁卡進出✔代收垃圾✔裝潢新✔秒殺',
#   'address_img_title': '✔電梯✔磁卡進出✔代收垃圾✔裝潢新✔秒殺',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6825745,
#   'region_name': '台北市',
#   'section_name': '中山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6842890,
#   'user_id': 158840,
#   'address': '天母西路41巷全新裝潢設計..',
#   'type': '1',
#   'post_id': 6842890,
#   'regionid': 1,
#   'sectionid': 8,
#   'streetid': 25451,
#   'room': 0,
#   'area': 5,
#   'price': '12,000',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1421953792,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '3分鐘內',
#   'updatetime': 1538114670,
#   'refreshtime': 1539176402,
#   'checkstatus': 5,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,lift,naturalgas,landpost,cartplace,cook,trabus,balcony_0,lease,bed,wardrobe,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2015/01/17/142147047245573806_210x158.crop.jpg',
#   'browsenum': 128,
#   'browsenum_all': 1657,
#   'floor2': 0,
#   'floor': 6,
#   'ltime': '2018-10-10 21:00:24',
#   'cases_id': '',
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '侯小姐',
#   'housetype': 1,
#   'street_name': '天母西路',
#   'alley_name': '41巷',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '全新裝潢設計風超優質套房出租',
#   'cases_name': '天母雅砌',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 6,
#   'floorInfo': '樓層：6/6',
#   'house_img': '120339161,120339162,120339163,120339164,120339165,120339584,121294766,121294775,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,士林租屋,獨立套房出租,全新裝潢設計風超優質套房出租',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '8',
#   'filename': 'https://hp2.591.com.tw/house/active/2015/01/17/142147047245573806_210x158.crop.jpg',
#   'nick_name': '屋主 侯小姐',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '士林區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '天母西路41巷全新裝潢設計風超優質套房出租',
#   'address_img_title': '全新裝潢設計風超優質套房出租',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6842890,
#   'region_name': '台北市',
#   'section_name': '士林區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6878409,
#   'user_id': 266409,
#   'address': '南京東路四段53巷小巨蛋捷..',
#   'type': '1',
#   'post_id': 6878409,
#   'regionid': 1,
#   'sectionid': 4,
#   'streetid': 26184,
#   'room': 0,
#   'area': 8,
#   'price': '13,000',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1498102949,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 1,
#   'houseage': 0,
#   'posttime': '8分鐘內',
#   'updatetime': 1538916875,
#   'refreshtime': 1539176102,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,naturalgas,landpost,trabus,balcony_0,lease,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2012/07/24/134313155737117203_210x158.crop.jpg',
#   'browsenum': 296,
#   'browsenum_all': 997,
#   'floor2': 0,
#   'floor': 4,
#   'ltime': '2018-10-10 21:00:05',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '鄭小姐',
#   'housetype': 1,
#   'street_name': '南京東路四段',
#   'alley_name': '53巷',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '小巨蛋捷運,新裝潢歐風設計木地板4F套房',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 5,
#   'floorInfo': '樓層：4/5',
#   'house_img': '121077473,121077474,121077475,121077476,121077477,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,松山租屋,獨立套房出租,小巨蛋捷運,新裝潢歐風設計木地板4F套房',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '5',
#   'filename': 'https://hp2.591.com.tw/house/active/2012/07/24/134313155737117203_210x158.crop.jpg',
#   'nick_name': '屋主 鄭小姐',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '松山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '南京東路四段53巷小巨蛋捷運,新裝潢歐風設計木地板4F套房',
#   'address_img_title': '小巨蛋捷運,新裝潢歐風設計木地板4F套房',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6878409,
#   'region_name': '台北市',
#   'section_name': '松山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6862613,
#   'user_id': 1562774,
#   'address': '廣州街萬華區全新套房隔壁..',
#   'type': '1',
#   'post_id': 6862613,
#   'regionid': 1,
#   'sectionid': 6,
#   'streetid': 26341,
#   'room': 0,
#   'area': 8,
#   'price': '15,000',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1522315258,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 3,
#   'houseage': 0,
#   'posttime': '13分鐘內',
#   'updatetime': 1538549395,
#   'refreshtime': 1539175802,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,landpost,balcony_1,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2015/11/13/144738056156155203_210x158.crop.jpg',
#   'browsenum': 118,
#   'browsenum_all': 916,
#   'floor2': 0,
#   'floor': 2,
#   'ltime': '2018-10-10 20:54:04',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '周先生',
#   'housetype': 1,
#   'street_name': '廣州街',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '261號',
#   'kind_name_img': '獨立套房',
#   'address_img': '萬華區全新套房隔壁龍山捷運站',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 3,
#   'floorInfo': '樓層：2/3',
#   'house_img': '120731613,120731614,120731615,120731616,120731617,120731618,120731619,120731620,120731621,120731622,120731623,120731624,120731625,120731626,120731627,120731628,120731629,120731630,120731631,120731632,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,萬華租屋,獨立套房出租,萬華區全新套房隔壁龍山捷運站',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '14',
#   'filename': 'https://hp1.591.com.tw/house/active/2015/11/13/144738056156155203_210x158.crop.jpg',
#   'nick_name': '屋主 周先生',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '萬華區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '廣州街萬華區全新套房隔壁龍山捷運站',
#   'address_img_title': '萬華區全新套房隔壁龍山捷運站',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6862613,
#   'region_name': '台北市',
#   'section_name': '萬華區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6869950,
#   'user_id': 192672,
#   'address': '昆明街西門捷運站旁精品套..',
#   'type': '1',
#   'post_id': 6869950,
#   'regionid': 1,
#   'sectionid': 6,
#   'streetid': 26313,
#   'room': 0,
#   'area': 15,
#   'price': '21,500',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1525933924,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '13分鐘內',
#   'updatetime': 1538711161,
#   'refreshtime': 1539175802,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,landpost,pet,cook,balcony_0,lease',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2011/05/17/130563639367114708_210x158.crop.jpg',
#   'browsenum': 177,
#   'browsenum_all': 1054,
#   'floor2': 0,
#   'floor': 7,
#   'ltime': '2018-10-10 20:54:04',
#   'cases_id': 10525,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '邱小姐',
#   'housetype': 1,
#   'street_name': '昆明街',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '46號',
#   'kind_name_img': '獨立套房',
#   'address_img': '西門捷運站旁精品套房出租(長短期皆可)',
#   'cases_name': '亞曼尼',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 8,
#   'floorInfo': '樓層：7/8',
#   'house_img': '120883666,120883667,120883668,120883669,120883670,120883671,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,萬華租屋,獨立套房出租,西門捷運站旁精品套房出租(長短期皆可)',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '6',
#   'filename': 'https://hp2.591.com.tw/house/active/2011/05/17/130563639367114708_210x158.crop.jpg',
#   'nick_name': '屋主 邱小姐',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '萬華區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '昆明街西門捷運站旁精品套房出租(長短期皆可)',
#   'address_img_title': '西門捷運站旁精品套房出租(長短期皆可)',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6869950,
#   'region_name': '台北市',
#   'section_name': '萬華區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 5676477,
#   'user_id': 236887,
#   'address': '中山北路三段公園樹海旁優..',
#   'type': '1',
#   'post_id': 5676477,
#   'regionid': 1,
#   'sectionid': 3,
#   'streetid': 25689,
#   'room': 0,
#   'area': 7.5,
#   'price': '10,000',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1442814473,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '28分鐘內',
#   'updatetime': 1539081089,
#   'refreshtime': 1539174902,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,landpost,balcony_0,bed,wardrobe,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2012/04/26/133541367307629405_210x158.crop.jpg',
#   'browsenum': 226,
#   'browsenum_all': 755,
#   'floor2': 0,
#   'floor': 4,
#   'ltime': '2018-10-10 20:36:28',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '李小姐',
#   'housetype': 1,
#   'street_name': '中山北路三段',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '32號',
#   'kind_name_img': '獨立套房',
#   'address_img': '公園樹海旁優質套房',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 7,
#   'floorInfo': '樓層：4/7',
#   'house_img': '96034423,96034424,96034425,96034426,96034427,96034428,96034429,96034430,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,中山租屋,獨立套房出租,公園樹海旁優質套房',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '8',
#   'filename': 'https://hp2.591.com.tw/house/active/2012/04/26/133541367307629405_210x158.crop.jpg',
#   'nick_name': '屋主 李小姐',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '中山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '中山北路三段公園樹海旁優質套房',
#   'address_img_title': '公園樹海旁優質套房',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 5676477,
#   'region_name': '台北市',
#   'section_name': '中山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6791617,
#   'user_id': 1526803,
#   'address': '忠孝西路一段套房出..',
#   'type': '1',
#   'post_id': 6791617,
#   'regionid': 1,
#   'sectionid': 1,
#   'streetid': 25790,
#   'room': 0,
#   'area': 8,
#   'price': '19,000',
#   'storeprice': 0,
#   'comment_total': 1,
#   'comment_unread': 1,
#   'comment_ltime': 1536924197,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '28分鐘內',
#   'updatetime': 1536744814,
#   'refreshtime': 1539174902,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,hotwater,four,broadband,landpost,pet,cook,trabus,balcony_0,lease,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2016/03/09/145750770347776009_210x158.crop.jpg',
#   'browsenum': 68,
#   'browsenum_all': 2057,
#   'floor2': 0,
#   'floor': 7,
#   'ltime': '2018-10-10 20:36:29',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '甘小姐',
#   'housetype': 1,
#   'street_name': '忠孝西路一段',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '套房出租飯店住房品質,平價收費,絕對物超',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 12,
#   'floorInfo': '樓層：7/12',
#   'house_img': '119249081,119249082,119249083,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,中正租屋,獨立套房出租,套房出租飯店住房品質,平價收費,絕對物超',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 1,
#   'comment_class': '',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '3',
#   'filename': 'https://hp1.591.com.tw/house/active/2016/03/09/145750770347776009_210x158.crop.jpg',
#   'nick_name': '屋主 甘小姐',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '中正區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '忠孝西路一段套房出租飯店住房品質,平價收費,絕對物超',
#   'address_img_title': '套房出租飯店住房品質,平價收費,絕對物超',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6791617,
#   'region_name': '台北市',
#   'section_name': '中正區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6843220,
#   'user_id': 996773,
#   'address': '南京東路三段233巷..',
#   'type': '1',
#   'post_id': 6843220,
#   'regionid': 1,
#   'sectionid': 3,
#   'streetid': 25725,
#   'room': 0,
#   'area': 6,
#   'price': '14,500',
#   'storeprice': 0,
#   'comment_total': 1,
#   'comment_unread': 0,
#   'comment_ltime': 1538544034,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 1,
#   'houseage': 0,
#   'posttime': '28分鐘內',
#   'updatetime': 1538119560,
#   'refreshtime': 1539174902,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,trabus,balcony_1,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2014/05/27/140118165247662402_210x158.crop.jpg',
#   'browsenum': 210,
#   'browsenum_all': 2906,
#   'floor2': 0,
#   'floor': 4,
#   'ltime': '2018-10-10 20:36:30',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '張先生',
#   'housetype': 3,
#   'street_name': '南京東路三段',
#   'alley_name': '233巷',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '文湖線~南京復興站~單身貴族首選',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 4,
#   'floorInfo': '樓層：4/4',
#   'house_img': '120348174,120348175,120348176,120348177,120348178,120348179,120348180,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,中山租屋,獨立套房出租,文湖線~南京復興站~單身貴族首選',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 1,
#   'comment_class': '',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '7',
#   'filename': 'https://hp1.591.com.tw/house/active/2014/05/27/140118165247662402_210x158.crop.jpg',
#   'nick_name': '仲介 張先生',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '中山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '南京東路三段233巷文湖線~南京復興站~單身貴族首選',
#   'address_img_title': '文湖線~南京復興站~單身貴族首選',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6843220,
#   'region_name': '台北市',
#   'section_name': '中山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6854255,
#   'user_id': 7350,
#   'address': '八德路四段[文青熟女宅]..',
#   'type': '1',
#   'post_id': 6854255,
#   'regionid': 1,
#   'sectionid': 4,
#   'streetid': 26157,
#   'room': 0,
#   'area': 20,
#   'price': '16,500',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1537778875,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 1,
#   'houseage': 0,
#   'posttime': '28分鐘內',
#   'updatetime': 1538386322,
#   'refreshtime': 1539174902,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,four,broadband,naturalgas,landpost,trabus,girl,balcony_0,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2015/09/18/144251559601639004_210x158.crop.jpg',
#   'browsenum': 273,
#   'browsenum_all': 2796,
#   'floor2': 0,
#   'floor': 4,
#   'ltime': '2018-10-10 20:36:30',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '莊先生',
#   'housetype': 1,
#   'street_name': '八德路四段',
#   'alley_name': '106巷',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '[文青熟女宅]南京三民捷運站，漫步8分鐘',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 4,
#   'floorInfo': '樓層：4/4',
#   'house_img': '120574890,120574891,120574892,120574893,120574894,120574895,120574896,120574897,120574898,120574899,120574900,120574901,120574902,120574903,120574904,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,松山租屋,獨立套房出租,[文青熟女宅]南京三民捷運站，漫步8分鐘',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '15',
#   'filename': 'https://hp2.591.com.tw/house/active/2015/09/18/144251559601639004_210x158.crop.jpg',
#   'nick_name': '屋主 莊先生',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '松山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '八德路四段[文青熟女宅]南京三民捷運站，漫步8分鐘',
#   'address_img_title': '[文青熟女宅]南京三民捷運站，漫步8分鐘',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6854255,
#   'region_name': '台北市',
#   'section_name': '松山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6854279,
#   'user_id': 7350,
#   'address': '汀州路二段地中海風格主題..',
#   'type': '1',
#   'post_id': 6854279,
#   'regionid': 1,
#   'sectionid': 1,
#   'streetid': 25776,
#   'room': 0,
#   'area': 5,
#   'price': '10,500',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 1,
#   'comment_ltime': 1538901506,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 1,
#   'houseage': 15,
#   'posttime': '28分鐘內',
#   'updatetime': 1538386381,
#   'refreshtime': 1539174902,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': 'advstore,market,night,park,school,hospital',
#   'condition': 'tv,cold,washer,hotwater,four,broadband,landpost,trabus,girl,balcony_0,bed,wardrobe',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2015/09/15/144229572037561406_210x158.crop.jpg',
#   'browsenum': 209,
#   'browsenum_all': 2007,
#   'floor2': 0,
#   'floor': 4,
#   'ltime': '2018-10-10 20:36:30',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '莊先生',
#   'housetype': 1,
#   'street_name': '汀州路二段',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '地中海風格主題套房，全數採用高級木質地板',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 4,
#   'floorInfo': '樓層：4/4',
#   'house_img': '120575479,120575480,120575481,120575482,120575483,120575484,120575485,120575486,120575487,120575488,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,中正租屋,獨立套房出租,地中海風格主題套房，全數採用高級木質地板',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '10',
#   'filename': 'https://hp2.591.com.tw/house/active/2015/09/15/144229572037561406_210x158.crop.jpg',
#   'nick_name': '屋主 莊先生',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '中正區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '汀州路二段地中海風格主題套房，全數採用高級木質地板',
#   'address_img_title': '地中海風格主題套房，全數採用高級木質地板',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6854279,
#   'region_name': '台北市',
#   'section_name': '中正區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6812571,
#   'user_id': 924877,
#   'address': '木柵路一段59巷世新大學超..',
#   'type': '1',
#   'post_id': 6812571,
#   'regionid': 1,
#   'sectionid': 12,
#   'streetid': 25921,
#   'room': 0,
#   'area': 7,
#   'price': '9,500',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1500451671,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 1,
#   'houseage': 0,
#   'posttime': '33分鐘內',
#   'updatetime': 1537889264,
#   'refreshtime': 1539174602,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': 'advstore,night,school',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,balcony_1,bed,wardrobe,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2017/09/05/150459470588267109_210x158.crop.jpg',
#   'browsenum': 162,
#   'browsenum_all': 4446,
#   'floor2': 0,
#   'floor': 5,
#   'ltime': '2018-10-10 20:36:03',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '江小姐',
#   'housetype': 2,
#   'street_name': '木柵路一段',
#   'alley_name': '59巷',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '世新大學超便宜美套房~獨立洗衣機~陽台~',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 5,
#   'floorInfo': '樓層：5/5',
#   'house_img': '119692455,119692456,119692457,119692458,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,文山租屋,獨立套房出租,世新大學超便宜美套房~獨立洗衣機~陽台~',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '4',
#   'filename': 'https://hp2.591.com.tw/house/active/2017/09/05/150459470588267109_210x158.crop.jpg',
#   'nick_name': '代理人 江小姐',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '文山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '木柵路一段59巷世新大學超便宜美套房~獨立洗衣機~陽台~',
#   'address_img_title': '世新大學超便宜美套房~獨立洗衣機~陽台~',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6812571,
#   'region_name': '台北市',
#   'section_name': '文山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6825950,
#   'user_id': 884313,
#   'address': '信義路四段265巷10..',
#   'type': '1',
#   'post_id': 6825950,
#   'regionid': 1,
#   'sectionid': 5,
#   'streetid': 25648,
#   'room': 0,
#   'area': 6,
#   'price': '19,000',
#   'storeprice': 0,
#   'comment_total': 1,
#   'comment_unread': 1,
#   'comment_ltime': 1537668946,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '33分鐘內',
#   'updatetime': 1537619162,
#   'refreshtime': 1539174602,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': '',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,landpost,cook,trabus,balcony_0,lease,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2018/09/22/153761822822910706_210x158.crop.jpg',
#   'browsenum': 186,
#   'browsenum_all': 3497,
#   'floor2': 0,
#   'floor': 13,
#   'ltime': '2018-10-10 20:36:04',
#   'cases_id': 7863,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '林小姐',
#   'housetype': 1,
#   'street_name': '信義路四段',
#   'alley_name': '265巷',
#   'lane_name': '',
#   'addr_number_name': '17號',
#   'kind_name_img': '獨立套房',
#   'address_img': '101信義安和站/台北飯店22800/月',
#   'cases_name': '小君悅',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 13,
#   'floorInfo': '樓層：13/13',
#   'house_img': '119984570,119984571,119984572,119984569,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,大安租屋,獨立套房出租,101信義安和站/台北飯店22800/月',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 1,
#   'comment_class': '',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '4',
#   'filename': 'https://hp2.591.com.tw/house/active/2018/09/22/153761822822910706_210x158.crop.jpg',
#   'nick_name': '屋主 林小姐',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '大安區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '信義路四段265巷101信義安和站/台北飯店22800/月',
#   'address_img_title': '101信義安和站/台北飯店22800/月',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6825950,
#   'region_name': '台北市',
#   'section_name': '大安區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6832641,
#   'user_id': 188345,
#   'address': '建國南路一段291巷..',
#   'type': '1',
#   'post_id': 6832641,
#   'regionid': 1,
#   'sectionid': 5,
#   'streetid': 25649,
#   'room': 0,
#   'area': 7,
#   'price': '17,500',
#   'storeprice': 0,
#   'comment_total': 1,
#   'comment_unread': 0,
#   'comment_ltime': 1538576841,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '33分鐘內',
#   'updatetime': 1538722250,
#   'refreshtime': 1539174602,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,landpost,cook,trabus,balcony_0,bed,wardrobe,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2018/10/01/153836508492049407_210x158.crop.jpg',
#   'browsenum': 149,
#   'browsenum_all': 2408,
#   'floor2': 0,
#   'floor': 4,
#   'ltime': '2018-10-10 20:36:04',
#   'cases_id': 4952,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '吳小姐',
#   'housetype': 1,
#   'street_name': '建國南路一段',
#   'alley_name': '291巷',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '近大安捷運站及大安森林公園',
#   'cases_name': '郵政新村',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 14,
#   'floorInfo': '樓層：4/14',
#   'house_img': '120128164,120128165,120128166,120529675,120530093,120529827,120529924,120529967,120530077,120529769,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,大安租屋,獨立套房出租,近大安捷運站及大安森林公園',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 1,
#   'comment_class': '',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '7',
#   'filename': 'https://hp1.591.com.tw/house/active/2018/10/01/153836508492049407_210x158.crop.jpg',
#   'nick_name': '屋主 吳小姐',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '大安區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '建國南路一段291巷近大安捷運站及大安森林公園',
#   'address_img_title': '近大安捷運站及大安森林公園',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6832641,
#   'region_name': '台北市',
#   'section_name': '大安區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6882079,
#   'user_id': 262898,
#   'address': '辛亥路四段101巷獨立套房..',
#   'type': '1',
#   'post_id': 6882079,
#   'regionid': 1,
#   'sectionid': 12,
#   'streetid': 25940,
#   'room': 0,
#   'area': 4,
#   'price': '7,000',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 0,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 3,
#   'houseage': 0,
#   'posttime': '33分鐘內',
#   'updatetime': 1538991002,
#   'refreshtime': 1539174602,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': 'advstore,market,park,school,hospital',
#   'condition': 'icebox,cold,washer,hotwater,broadband,landpost,trabus,balcony_1,bed,wardrobe,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2018/10/08/153898955029625705_210x158.crop.jpg',
#   'browsenum': 301,
#   'browsenum_all': 707,
#   'floor2': 0,
#   'floor': 3,
#   'ltime': '2018-10-10 20:36:05',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '林媽媽',
#   'housetype': 1,
#   'street_name': '辛亥路四段',
#   'alley_name': '101巷',
#   'lane_name': '93弄',
#   'addr_number_name': '15號',
#   'kind_name_img': '獨立套房',
#   'address_img': '獨立套房~近捷運辛亥站、靈糧山莊辛亥國小',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 3,
#   'floorInfo': '樓層：3/3',
#   'house_img': '121150563,121150576,121150610,121150634,121150643,121150649,121150652,121150658,121150671,121150813,121150833,121150901,121151049,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,文山租屋,獨立套房出租,獨立套房~近捷運辛亥站、靈糧山莊辛亥國小',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '13',
#   'filename': 'https://hp1.591.com.tw/house/active/2018/10/08/153898955029625705_210x158.crop.jpg',
#   'nick_name': '屋主 林媽媽',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '文山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '辛亥路四段101巷獨立套房~近捷運辛亥站、靈糧山莊辛亥國小',
#   'address_img_title': '獨立套房~近捷運辛亥站、靈糧山莊辛亥國小',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6882079,
#   'region_name': '台北市',
#   'section_name': '文山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6888383,
#   'user_id': 1669983,
#   'address': '伊通街52巷舒適採光套房步..',
#   'type': '1',
#   'post_id': 6888383,
#   'regionid': 1,
#   'sectionid': 3,
#   'streetid': 25710,
#   'room': 0,
#   'area': 8,
#   'price': '11,500',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1527775174,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 1,
#   'houseage': 0,
#   'posttime': '33分鐘內',
#   'updatetime': 1539152883,
#   'refreshtime': 1539174602,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,landpost,pet,cook,trabus,balcony_1,bed,wardrobe,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2018/05/28/152747633930794001_210x158.crop.jpg',
#   'browsenum': 0,
#   'browsenum_all': 255,
#   'floor2': 0,
#   'floor': 4,
#   'ltime': '2018-10-10 20:36:06',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '朱先生',
#   'housetype': 1,
#   'street_name': '伊通街',
#   'alley_name': '52巷',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '舒適採光套房步行松江南京一分鐘小資族首選',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 5,
#   'floorInfo': '樓層：4/5',
#   'house_img': '121283606,121283607,121283608,121283609,121283610,121283611,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,中山租屋,獨立套房出租,舒適採光套房步行松江南京一分鐘小資族首選',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '6',
#   'filename': 'https://hp2.591.com.tw/house/active/2018/05/28/152747633930794001_210x158.crop.jpg',
#   'nick_name': '屋主 朱先生',
#   'new_img': '<div class="isNew"></div>',
#   'regionname': '台北市',
#   'sectionname': '中山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '伊通街52巷舒適採光套房步行松江南京一分鐘小資族首選',
#   'address_img_title': '舒適採光套房步行松江南京一分鐘小資族首選',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6888383,
#   'region_name': '台北市',
#   'section_name': '中山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6869128,
#   'user_id': 910049,
#   'address': '南京東路三段303巷小巨蛋..',
#   'type': '1',
#   'post_id': 6869128,
#   'regionid': 1,
#   'sectionid': 4,
#   'streetid': 26182,
#   'room': 0,
#   'area': 20,
#   'price': '25,500',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 0,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 5,
#   'houseage': 0,
#   'posttime': '43分鐘內',
#   'updatetime': 1539003816,
#   'refreshtime': 1539174002,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,landpost,cook,balcony_0,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2018/10/05/153868917067900405_210x158.crop.jpg',
#   'browsenum': 101,
#   'browsenum_all': 733,
#   'floor2': 0,
#   'floor': 3,
#   'ltime': '2018-10-10 20:24:04',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '賴小姐',
#   'housetype': 1,
#   'street_name': '南京東路三段',
#   'alley_name': '303巷',
#   'lane_name': '14弄',
#   'addr_number_name': '6號',
#   'kind_name_img': '獨立套房',
#   'address_img': '小巨蛋旁/24小時保全/敦化國小學區',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 7,
#   'floorInfo': '樓層：3/7',
#   'house_img': '120868734,120868786,120868736,120868789,120868735,120868767,120868765,120868769,120868784,120868787,120868790,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,松山租屋,獨立套房出租,小巨蛋旁/24小時保全/敦化國小學區',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '11',
#   'filename': 'https://hp1.591.com.tw/house/active/2018/10/05/153868917067900405_210x158.crop.jpg',
#   'nick_name': '屋主 賴小姐',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '松山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '南京東路三段303巷小巨蛋旁/24小時保全/敦化國小學區',
#   'address_img_title': '小巨蛋旁/24小時保全/敦化國小學區',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6869128,
#   'region_name': '台北市',
#   'section_name': '松山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6813582,
#   'user_id': 1350522,
#   'address': '市民大道四段女性專..',
#   'type': '1',
#   'post_id': 6813582,
#   'regionid': 1,
#   'sectionid': 4,
#   'streetid': 26162,
#   'room': 0,
#   'area': 7,
#   'price': '11,000',
#   'storeprice': 0,
#   'comment_total': 2,
#   'comment_unread': 1,
#   'comment_ltime': 1539092022,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '48分鐘內',
#   'updatetime': 1538991750,
#   'refreshtime': 1539173702,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,lift,landpost,cook,trabus,girl,balcony_0,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2018/09/18/153728308202707703_210x158.crop.jpg',
#   'browsenum': 206,
#   'browsenum_all': 4225,
#   'floor2': 0,
#   'floor': 2,
#   'ltime': '2018-10-10 20:18:04',
#   'cases_id': '',
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '李先生',
#   'housetype': 1,
#   'street_name': '市民大道四段',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '女性專屬安全舒適寧靜套房',
#   'cases_name': '華南別墅',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 7,
#   'floorInfo': '樓層：2/7',
#   'house_img': '119714927,119714929,119714930,119714931,119714932,119714933,119714934,119714935,119714937,119714938,119714940,119714942,119714943,119714945,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,松山租屋,獨立套房出租,女性專屬安全舒適寧靜套房',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 2,
#   'comment_class': '',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '14',
#   'filename': 'https://hp1.591.com.tw/house/active/2018/09/18/153728308202707703_210x158.crop.jpg',
#   'nick_name': '屋主 李先生',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '松山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '市民大道四段女性專屬安全舒適寧靜套房',
#   'address_img_title': '女性專屬安全舒適寧靜套房',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6813582,
#   'region_name': '台北市',
#   'section_name': '松山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6856881,
#   'user_id': 1790444,
#   'address': '撫遠街255巷民生社區陽光..',
#   'type': '1',
#   'post_id': 6856881,
#   'regionid': 1,
#   'sectionid': 4,
#   'streetid': 26197,
#   'room': 0,
#   'area': 17,
#   'price': '18,500',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1536412749,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 1,
#   'houseage': 0,
#   'posttime': '48分鐘內',
#   'updatetime': 1538450127,
#   'refreshtime': 1539173702,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': 'advstore,market,park,school',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,naturalgas,landpost,trabus,balcony_1,bed,wardrobe,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2018/09/27/153805774046137601_210x158.crop.jpg',
#   'browsenum': 160,
#   'browsenum_all': 1388,
#   'floor2': 0,
#   'floor': 3,
#   'ltime': '2018-10-10 20:18:05',
#   'cases_id': 22880,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '蔡太太',
#   'housetype': 1,
#   'street_name': '撫遠街',
#   'alley_name': '255巷',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '民生社區陽光宅1房1廳，適合2人同住',
#   'cases_name': '民生社區',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 4,
#   'floorInfo': '樓層：3/4',
#   'house_img': '120621683,120621684,120621685,120621686,120621687,120621688,120621689,120621690,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,松山租屋,獨立套房出租,民生社區陽光宅1房1廳，適合2人同住',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '8',
#   'filename': 'https://hp2.591.com.tw/house/active/2018/09/27/153805774046137601_210x158.crop.jpg',
#   'nick_name': '屋主 蔡太太',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '松山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '撫遠街255巷民生社區陽光宅1房1廳，適合2人同住',
#   'address_img_title': '民生社區陽光宅1房1廳，適合2人同住',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6856881,
#   'region_name': '台北市',
#   'section_name': '松山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6814542,
#   'user_id': 896133,
#   'address': '農安街高品質豪宅大樓精緻..',
#   'type': '1',
#   'post_id': 6814542,
#   'regionid': 1,
#   'sectionid': 3,
#   'streetid': 25744,
#   'room': 0,
#   'area': 16,
#   'price': '28,000',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1466013589,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '53分鐘內',
#   'updatetime': 1538707871,
#   'refreshtime': 1539173402,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,broadband,lift,landpost,cook,trabus,balcony_1,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2018/10/05/153870784294802205_210x158.crop.jpg',
#   'browsenum': 90,
#   'browsenum_all': 2205,
#   'floor2': 0,
#   'floor': 3,
#   'ltime': '2018-10-10 20:12:03',
#   'cases_id': 254,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '楊小姐',
#   'housetype': 1,
#   'street_name': '農安街',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '高品質豪宅大樓精緻裝潢設備齊全生活機能佳',
#   'cases_name': '基泰之星',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 14,
#   'floorInfo': '樓層：3/14',
#   'house_img': '119734491,119734492,119734493,119734494,119734495,119734496,119734501,119734504,119734505,119800096,119800174,119800344,119869393,120880976,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,中山租屋,獨立套房出租,高品質豪宅大樓精緻裝潢設備齊全生活機能佳',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '14',
#   'filename': 'https://hp1.591.com.tw/house/active/2018/10/05/153870784294802205_210x158.crop.jpg',
#   'nick_name': '屋主 楊小姐',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '中山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '農安街高品質豪宅大樓精緻裝潢設備齊全生活機能佳',
#   'address_img_title': '高品質豪宅大樓精緻裝潢設備齊全生活機能佳',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6814542,
#   'region_name': '台北市',
#   'section_name': '中山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6818125,
#   'user_id': 645827,
#   'address': '重慶北路四段可租一個月可..',
#   'type': '1',
#   'post_id': 6818125,
#   'regionid': 1,
#   'sectionid': 8,
#   'streetid': 25507,
#   'room': 99,
#   'area': 8,
#   'price': '8,800',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1534852559,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 1,
#   'houseage': 0,
#   'posttime': '53分鐘內',
#   'updatetime': 1538375855,
#   'refreshtime': 1539173402,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': '',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,landpost,cook,balcony_0,lease,bed,wardrobe,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2013/11/25/138537047295167607_210x158.crop.jpg',
#   'browsenum': 169,
#   'browsenum_all': 3200,
#   'floor2': 0,
#   'floor': 4,
#   'ltime': '2018-10-10 20:12:03',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '杜先生',
#   'housetype': 1,
#   'street_name': '重慶北路四段',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '可租一個月可短期',
#   'cases_name': '',
#   'layout': '開放式格局',
#   'layout_str': '',
#   'allfloor': 5,
#   'floorInfo': '樓層：4/5',
#   'house_img': '119807710,119807711,119807712,119807713,119807714,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,士林租屋,獨立套房出租,可租一個月可短期',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
# ...
#   'kind': 2,
#   'shape': 1,
#   'houseage': 22,
#   'posttime': '58分鐘內',
#   'updatetime': 1539173095,
#   'refreshtime': 1539173102,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,landpost,isleastrent,pet,trabus,balcony_0,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2018/10/07/153887689413780701_210x158.crop.jpg',
#   'browsenum': 233,
#   'browsenum_all': 4472,
#   'floor2': 0,
#   'floor': 4,
#   'ltime': '2018-10-10 20:08:00',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '游先生',
#   'housetype': 1,
#   'street_name': '橫科路',
#   'alley_name': '4巷',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '南港展館捷運站走4分#房間及廁所有對外窗',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 5,
#   'floorInfo': '樓層：4/5',
#   'house_img': '121034555,121034569,121184203,121184208,121034637,121034486,121184204,121216274,120151352,120151353,120151354,120151355,120151357,121184256,121184273,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,南港租屋,獨立套房出租,南港展館捷運站走4分#房間及廁所有對外窗',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '15',
#   'filename': 'https://hp2.591.com.tw/house/active/2018/10/07/153887689413780701_210x158.crop.jpg',
#   'nick_name': '屋主 游先生',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '南港區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '橫科路4巷南港展館捷運站走4分#房間及廁所有對外窗',
#   'address_img_title': '南港展館捷運站走4分#房間及廁所有對外窗',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6833887,
#   'region_name': '台北市',
#   'section_name': '南港區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6847670,
#   'user_id': 601747,
#   'address': '吳興街220巷全新裝潢套房..',
#   'type': '1',
#   'post_id': 6847670,
#   'regionid': 1,
#   'sectionid': 7,
#   'streetid': 26212,
#   'room': 0,
#   'area': 7,
#   'price': '13,500',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1454745592,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 1,
#   'houseage': 0,
#   'posttime': '58分鐘內',
#   'updatetime': 1538233322,
#   'refreshtime': 1539173102,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': 'advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,naturalgas,landpost,trabus,girl,balcony_0,bed,wardrobe,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2014/01/21/139030852710070404_210x158.crop.jpg',
#   'browsenum': 85,
#   'browsenum_all': 1134,
#   'floor2': 0,
#   'floor': 2,
#   'ltime': '2018-10-10 20:08:00',
#   'cases_id': '',
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '李先生',
#   'housetype': 1,
#   'street_name': '吳興街',
#   'alley_name': '220巷',
#   'lane_name': '59弄',
#   'addr_number_name': '1號',
#   'kind_name_img': '獨立套房',
#   'address_img': '全新裝潢套房出租',
#   'cases_name': '克勤新城',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 5,
#   'floorInfo': '樓層：2/5',
#   'house_img': '120451479,120451480,120451481,120451482,120451483,120451484,120451485,120451486,120451487,120451488,120451489,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,信義租屋,獨立套房出租,全新裝潢套房出租',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '7',
#   'filename': 'https://hp1.591.com.tw/house/active/2014/01/21/139030852710070404_210x158.crop.jpg',
#   'nick_name': '屋主 李先生',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '信義區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '吳興街220巷全新裝潢套房出租',
#   'address_img_title': '全新裝潢套房出租',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6847670,
#   'region_name': '台北市',
#   'section_name': '信義區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6888790,
#   'user_id': 158840,
#   'address': '復興南路一段忠孝復興300m..',
#   'type': '1',
#   'post_id': 6888790,
#   'regionid': 1,
#   'sectionid': 5,
#   'streetid': 25660,
#   'room': 0,
#   'area': 8,
#   'price': '25,000',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 0,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '58分鐘內',
#   'updatetime': 1539147871,
#   'refreshtime': 1539173102,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': '',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,lift,landpost,cook,trabus,balcony_1,lease,bed,wardrobe,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2018/10/10/153914753486924404_210x158.crop.jpg',
#   'browsenum': 0,
#   'browsenum_all': 113,
#   'floor2': 0,
#   'floor': 7,
#   'ltime': '2018-10-10 20:08:02',
#   'cases_id': 95973,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '田先生',
#   'housetype': 1,
#   'street_name': '復興南路一段',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '忠孝復興300m走路4分_Loft風套房',
#   'cases_name': '三普安和',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 16,
#   'floorInfo': '樓層：7/16',
#   'house_img': '121293451,121293497,121293509,121293529,121293541,121293599,121293692,121293707,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,大安租屋,獨立套房出租,忠孝復興300m走路4分_Loft風套房',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '8',
#   'filename': 'https://hp1.591.com.tw/house/active/2018/10/10/153914753486924404_210x158.crop.jpg',
#   'nick_name': '屋主 田先生',
#   'new_img': '<div class="isNew"></div>',
#   'regionname': '台北市',
#   'sectionname': '大安區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '復興南路一段忠孝復興300m走路4分_Loft風套房',
#   'address_img_title': '忠孝復興300m走路4分_Loft風套房',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6888790,
#   'region_name': '台北市',
#   'section_name': '大安區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6889630,
#   'user_id': 177257,
#   'address': '忠孝東路五段信義商..',
#   'type': '1',
#   'post_id': 6889630,
#   'regionid': 1,
#   'sectionid': 7,
#   'streetid': 26214,
#   'room': 0,
#   'area': 20,
#   'price': '28,000',
#   'storeprice': 0,
#   'comment_total': 1,
#   'comment_unread': 1,
#   'comment_ltime': 1539166527,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '58分鐘內',
#   'updatetime': 1539162123,
#   'refreshtime': 1539173102,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,lift,naturalgas,landpost,cook,trabus,balcony_1,bed,wardrobe,sofa,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2018/10/10/153916154398221904_210x158.crop.jpg',
#   'browsenum': 0,
#   'browsenum_all': 74,
#   'floor2': 0,
#   'floor': 7,
#   'ltime': '2018-10-10 20:08:02',
#   'cases_id': 18110,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '張先生',
#   'housetype': 1,
#   'street_name': '忠孝東路五段',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '信義商圈優質小套房一只皮箱即可入住',
#   'cases_name': 'EAT',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 11,
#   'floorInfo': '樓層：7/11',
#   'house_img': '121313438,121313431,121313440,121313443,121313445,121313449,121313450,121313428,121313452,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,信義租屋,獨立套房出租,信義商圈優質小套房一只皮箱即可入住',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 1,
#   'comment_class': '',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '9',
#   'filename': 'https://hp1.591.com.tw/house/active/2018/10/10/153916154398221904_210x158.crop.jpg',
#   'nick_name': '屋主 張先生',
#   'new_img': '<div class="isNew"></div>',
#   'regionname': '台北市',
#   'sectionname': '信義區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '忠孝東路五段信義商圈優質小套房一只皮箱即可入住',
#   'address_img_title': '信義商圈優質小套房一只皮箱即可入住',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6889630,
#   'region_name': '台北市',
#   'section_name': '信義區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 5504618,
#   'user_id': 867772,
#   'address': '中山北路一段96巷近北車24..',
#   'type': '1',
#   'post_id': 5504618,
#   'regionid': 1,
#   'sectionid': 3,
#   'streetid': 25687,
#   'room': 0,
#   'area': 10,
#   'price': '16,000',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 0,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 1,
#   'houseage': 0,
#   'posttime': '2小時內',
#   'updatetime': 1538866719,
#   'refreshtime': 1539172802,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': '',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,landpost,trabus,balcony_0,bed,wardrobe,sofa',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2016/06/22/146657890983916701_210x158.crop.jpg',
#   'browsenum': 131,
#   'browsenum_all': 511,
#   'floor2': 0,
#   'floor': 2,
#   'ltime': '2018-10-10 20:06:03',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '張先生',
#   'housetype': 1,
#   'street_name': '中山北路一段',
#   'alley_name': '96巷',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '近北車24H安全監控禁菸',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 5,
#   'floorInfo': '樓層：2/5',
#   'house_img': '92504153,92504154,92504155,92504156,92504157,92504158,92504159,92504160,92504161,92504162,92504163,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,中山租屋,獨立套房出租,近北車24H安全監控禁菸',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '11',
#   'filename': 'https://hp2.591.com.tw/house/active/2016/06/22/146657890983916701_210x158.crop.jpg',
#   'nick_name': '屋主 張先生',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '中山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '中山北路一段96巷近北車24H安全監控禁菸',
#   'address_img_title': '近北車24H安全監控禁菸',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 5504618,
#   'region_name': '台北市',
#   'section_name': '中山區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6870833,
#   'user_id': 915426,
#   'address': '羅斯福路三段花園套房含水..',
#   'type': '1',
#   'post_id': 6870833,
#   'regionid': 1,
#   'sectionid': 5,
#   'streetid': 25680,
#   'room': 0,
#   'area': 10,
#   'price': '25,000',
#   'storeprice': 0,
#   'comment_total': 0,
#   'comment_unread': 0,
#   'comment_ltime': 1538070373,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '2小時內',
#   'updatetime': 1538719040,
#   'refreshtime': 1539172802,
#   'checkstatus': 1,
#   'status': '',
#   'closed': 0,
#   'living': 'advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,lift,naturalgas,landpost,trabus,balcony_0,bed,wardrobe,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp1.591.com.tw/house/active/2018/09/04/153604451256126209_210x158.crop.jpg',
#   'browsenum': 92,
#   'browsenum_all': 588,
#   'floor2': 0,
#   'floor': 12,
#   'ltime': '2018-10-10 20:07:05',
#   'cases_id': '',
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '黃先生',
#   'housetype': 1,
#   'street_name': '羅斯福路三段',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '花園套房含水.電.瓦斯.一只皮箱即可入住',
#   'cases_name': '羅德大樓',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 12,
#   'floorInfo': '樓層：12/12',
#   'house_img': '120901741,120901742,120901743,120901744,120901745,120901746,120901747,120901748,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,大安租屋,獨立套房出租,花園套房含水.電.瓦斯.一只皮箱即可入住',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 0,
#   'comment_class': 'none',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '8',
#   'filename': 'https://hp1.591.com.tw/house/active/2018/09/04/153604451256126209_210x158.crop.jpg',
#   'nick_name': '屋主 黃先生',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '大安區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '羅斯福路三段花園套房含水.電.瓦斯.一只皮箱即可入住',
#   'address_img_title': '花園套房含水.電.瓦斯.一只皮箱即可入住',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6870833,
#   'region_name': '台北市',
#   'section_name': '大安區',
#   'addInfo': '',
#   'onepxImg': ''},
#  {'id': 6792629,
#   'user_id': 647819,
#   'address': '新生北路三段中山國..',
#   'type': '1',
#   'post_id': 6792629,
#   'regionid': 1,
#   'sectionid': 3,
#   'streetid': 25743,
#   'room': 0,
#   'area': 6.5,
#   'price': '13,500',
#   'storeprice': 0,
#   'comment_total': 1,
#   'comment_unread': 6,
#   'comment_ltime': 1538544378,
#   'hasimg': 1,
#   'kind': 2,
#   'shape': 2,
#   'houseage': 0,
#   'posttime': '2小時內',
#   'updatetime': 1537964009,
#   'refreshtime': 1539172502,
#   'checkstatus': 0,
#   'status': '',
#   'closed': 0,
#   'living': 'depart,advstore,market,night,park,school,hospital',
#   'condition': 'tv,icebox,cold,washer,hotwater,four,broadband,lift,landpost,cook,trabus,balcony_0,bed,wardrobe,bookTable,chair',
#   'isvip': 1,
#   'mvip': 1,
#   'is_combine': 1,
#   'cover': 'https://hp2.591.com.tw/house/active/2018/09/19/153737193245335606_210x158.crop.jpg',
#   'browsenum': 155,
#   'browsenum_all': 6037,
#   'floor2': 0,
#   'floor': 11,
#   'ltime': '2018-10-10 20:00:02',
#   'cases_id': 0,
#   'social_house': 0,
#   'distance': 0,
#   'search_name': '',
#   'mainarea': None,
#   'balcony_area': None,
#   'groundarea': None,
#   'linkman': '周太太',
#   'housetype': 1,
#   'street_name': '新生北路三段',
#   'alley_name': '',
#   'lane_name': '',
#   'addr_number_name': '',
#   'kind_name_img': '獨立套房',
#   'address_img': '中山國小捷運站-電梯-大窗',
#   'cases_name': '',
#   'layout': '',
#   'layout_str': '',
#   'allfloor': 12,
#   'floorInfo': '樓層：11/12',
#   'house_img': '119791838,119791605,120217824,120217844,120217842,120217835,120217827,119989830,119791610,119989831,120217832,120217837,120218164,120218167,120218171,',
#   'houseimg': None,
#   'cartplace': '',
#   'space_type_str': '',
#   'photo_alt': '台北租屋,中山租屋,獨立套房出租,中山國小捷運站-電梯-大窗',
#   'addition4': 1,
#   'addition2': 0,
#   'addition3': 0,
#   'vipimg': '',
#   'vipstyle': 'isvip',
#   'vipBorder': 'vipStyle',
#   'new_list_comment_total': 1,
#   'comment_class': '',
#   'price_hide': 'price-hide',
#   'kind_name': '獨立套房',
#   'photoNum': '15',
#   'filename': 'https://hp2.591.com.tw/house/active/2018/09/19/153737193245335606_210x158.crop.jpg',
#   'nick_name': '屋主 周太太',
#   'new_img': '',
#   'regionname': '台北市',
#   'sectionname': '中山區',
#   'icon_name': '出租',
#   'icon_class': 'rent',
#   'fulladdress': '新生北路三段中山國小捷運站-電梯-大窗',
#   'address_img_title': '中山國小捷運站-電梯-大窗',
#   'browsenum_name': '昨日瀏覽',
#   'unit': '元/月',
#   'houseid': 6792629,
#   'region_name': '台北市',
#   'section_name': '中山區',
#   'addInfo': '',
#   'onepxImg': ''}]

# %% [markdown]
# # Use crhome devtool to find json files
# * Slide: https://docs.google.com/presentation/d/e/2PACX-1vRW84XoB5sFRT1Eg-GrK4smX23qoNkFffz_h8oRU4AIvJAgrrxBn8059_0UeHv_pFBks_Z37vNbLGai/pub?start=false&loop=false&delayms=3000

# %%
headers = {
    'User-Agent': 'Chrome/69.0.3497.100'
} # headers are sent by dict form

# %%
res = requests.get(url_591, headers=headers).json()
all_data = res["data"]["data"]
res.keys()
res["records"]
# Out:
# '2,414'

# %%
total_page = int(res["records"].replace(",", ""))
print(total_page)
url = "https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind=2&searchtype=1&region=1&firstRow={}&totalRows={}".format(0*30, total_page)
url = "https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind=2&searchtype=1&region=1&firstRow={}&totalRows={}".format(1*30, total_page)
url = "https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind=2&searchtype=1&region=1&firstRow={}&totalRows={}".format(2*30, total_page)
url = "https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind=2&searchtype=1&region=1&firstRow={}&totalRows={}".format(3*30, total_page)
res = requests.get(url_591, headers=headers).json()
res.keys()
# Out:
# 2414
# dict_keys(['status', 'data', 'records', 'is_recom', 'deal_recom', 'online_social_user'])

# %%
int(total_page/30)
all_data = []

# %%
all_data = []
for i in range(0, int(total_page/30)+1):
    url = "https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind=2&searchtype=1&region=1&firstRow={}&totalRows={}".format(i*30, total_page)
    res = requests.get(url, headers=headers).json()
    all_data.extend(res["data"]["data"])
    print(i, len(all_data))
# Out:
# 0 30
# 1 60
# 2 90
# 3 120
# 4 150
# 5 180
# 6 210
# 7 240
# 8 270
# 9 300
# 10 330
# 11 360
# 12 390
# 13 420
# 14 450
# 15 480
# 16 510
# 17 540
# 18 570
# 19 600
# 20 630
# 21 660
# 22 690
# 23 720
# 24 750
# 25 780
# 26 810
# 27 840
# 28 870
# 29 900
# 30 930
# 31 960
# 32 990
# 33 1020
# 34 1050
# 35 1080
# 36 1110
# 37 1140
# 38 1170
# 39 1200
# 40 1230
# 41 1260
# 42 1290
# 43 1320
# 44 1350
# 45 1380
# 46 1410
# 47 1440
# 48 1470
# 49 1500
# 50 1530
# 51 1560
# 52 1590
# 53 1620
# 54 1650
# 55 1680
# 56 1710
# 57 1740
# 58 1770
# 59 1800
# 60 1830
# 61 1860
# 62 1890
# 63 1920
# 64 1950
# 65 1980
# 66 2010
# 67 2040
# 68 2070
# 69 2100
# 70 2130
# 71 2160
# 72 2190
# 73 2220
# 74 2250
# 75 2280
# 76 2310
# 77 2340
# 78 2370
# 79 2400
# 80 2414

# %%
import pandas as pd
rent591_df = pd.DataFrame(all_data)
rent591_df.head()
# Out:
#   addInfo  addition2  addition3  addition4 addr_number_name          address  \
# 0                  0          0          1             330號  信義路五段150巷象山旁新..
# 1                  0          0          1              27號   塔悠路出租河堤景觀套房，..
# 2                  0          0          1                   南京東路四段133巷近小巨..
# 3                  0          0          1                    中華路一段English..
# 4                  0          0          1                   仙岩路58巷科大世新獨立套..
#
#             address_img     address_img_title alley_name  allfloor    ...     \
# 0     象山旁新裝潢工業風小套房，雜費全包     象山旁新裝潢工業風小套房，雜費全包       150巷        13    ...
# 1  出租河堤景觀套房，近饒河夜市，南港，內科  出租河堤景觀套房，近饒河夜市，南港，內科                   11    ...
# 2  近小巨蛋.健康路.松山新城.育達.寧安街  近小巨蛋.健康路.松山新城.育達.寧安街       133巷         6    ...
# 3  English新裝潢西門捷運電梯一房一廳  English新裝潢西門捷運電梯一房一廳                   12    ...
# 4      科大世新獨立套房採光佳有陽台包網      科大世新獨立套房採光佳有陽台包網        58巷         6    ...
#
#    storeprice street_name  streetid  type unit  updatetime  user_id vipBorder  \
# 0           0       信義路五段     26234     1  元/月  1537977490  1702300  vipStyle
# 1           0         塔悠路     26192     1  元/月  1537169020  1077174  vipStyle
# 2           0      南京東路四段     26184     1  元/月  1539069855   413312  vipStyle
# 3           0       中華路一段     26295     1  元/月  1538897991   266409  vipStyle
# 4           0         仙岩路     25928     1  元/月  1538140234   129411  vipStyle
#
#    vipimg  vipstyle
# 0             isvip
# 1             isvip
# 2             isvip
# 3             isvip
# 4             isvip
#
# [5 rows x 88 columns]

# %% [markdown]
# # Dump files for backup
#
# ## Dump one variable to json

# %%
import json
with open('rent_591.json', 'w') as outfile:
    json.dump(all_data, outfile)

# %% [markdown]
# ## Dump multiple variables to pickle

# %%
import pickle
with open('rent591.pkl', 'wb') as f:  # Python 3: open(..., 'wb')
    pickle.dump([all_data, rent591_df], f)

# %% [markdown]
# ## Load multiple variables back to objects

# %%
with open('rent591.pkl', "rb") as f:  # Python 3: open(..., 'rb')
    rent591_list, rent591_df2 = pickle.load(f)

# %%
len(rent591_list)
# Out:
# 2414

# %%
rent591_df2.describe()
# Out:
#          addition2  addition3    addition4     allfloor         area  \
# count  2414.000000     2414.0  2414.000000  2414.000000  2414.000000
# mean      0.001243        0.0     0.032312     8.335128    10.194118
# std       0.035238        0.0     0.176863     5.474421     4.271879
# min       0.000000        0.0     0.000000     1.000000     3.000000
# 25%       0.000000        0.0     0.000000     4.000000     7.000000
# 50%       0.000000        0.0     0.000000     7.000000     9.500000
# 75%       0.000000        0.0     0.000000    12.000000    13.000000
# max       1.000000        0.0     1.000000   121.000000    38.000000
#
#          browsenum  browsenum_all  checkstatus  closed  comment_ltime  \
# count  2414.000000    2414.000000  2414.000000  2414.0   2.414000e+03
# mean     60.536040     850.626346     0.762635     0.0   7.610690e+08
# std      58.292908    1004.820779     0.937100     0.0   7.552827e+08
# min       0.000000       1.000000     0.000000     0.0   0.000000e+00
# 25%      21.000000     229.000000     0.000000     0.0   0.000000e+00
# 50%      44.000000     516.000000     1.000000     0.0   1.291179e+09
# 75%      81.000000    1099.500000     1.000000     0.0   1.536105e+09
# max     574.000000   13206.000000     5.000000     0.0   1.539188e+09
#
#            ...        refreshtime  regionid         room    sectionid  \
# count      ...       2.414000e+03    2414.0  2414.000000  2414.000000
# mean       ...       1.538912e+09       1.0     2.543496     5.552196
# std        ...       7.474037e+05       0.0    15.663882     3.047009
# min        ...       1.511853e+09       1.0     0.000000     1.000000
# 25%        ...       1.538996e+09       1.0     0.000000     3.000000
# 50%        ...       1.539136e+09       1.0     0.000000     5.000000
# 75%        ...       1.539168e+09       1.0     0.000000     8.000000
# max        ...       1.539189e+09       1.0    99.000000    12.000000
#
#              shape  social_house  storeprice      streetid    updatetime  \
# count  2414.000000   2414.000000      2414.0   2414.000000  2.414000e+03
# mean      1.714167      0.008285         0.0  26796.160315  1.538395e+09
# std       0.700120      0.090663         0.0   5449.111388  9.501974e+05
# min       1.000000      0.000000         0.0  25425.000000  1.511853e+09
# 25%       1.000000      0.000000         0.0  25687.000000  1.538022e+09
# 50%       2.000000      0.000000         0.0  25787.000000  1.538635e+09
# 75%       2.000000      0.000000         0.0  26172.750000  1.538993e+09
# max       6.000000      1.000000         0.0  69947.000000  1.539189e+09
#
#             user_id
# count  2.414000e+03
# mean   1.043620e+06
# std    7.847464e+05
# min    1.258000e+03
# 25%    3.074432e+05
# 50%    9.255255e+05
# 75%    1.708152e+06
# max    2.482651e+06
#
# [8 rows x 36 columns]
